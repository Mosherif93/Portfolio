# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing data

# %%
df=pd.read_csv("customer_shopping_data.csv")
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# # Exploring the data

# %%
df.shape
# Out:
# (99457, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
df.describe(include="all")
# Out:
#        invoice_no customer_id  gender           age  category      quantity  \
# count       99457       99457   99457  99457.000000     99457  99457.000000
# unique      99457       99457       2           NaN         8           NaN
# top       I138884     C241288  Female           NaN  Clothing           NaN
# freq            1           1   59482           NaN     34487           NaN
# mean          NaN         NaN     NaN     43.427089       NaN      3.003429
# std           NaN         NaN     NaN     14.990054       NaN      1.413025
# min           NaN         NaN     NaN     18.000000       NaN      1.000000
# 25%           NaN         NaN     NaN     30.000000       NaN      2.000000
# 50%           NaN         NaN     NaN     43.000000       NaN      3.000000
# 75%           NaN         NaN     NaN     56.000000       NaN      4.000000
# max           NaN         NaN     NaN     69.000000       NaN      5.000000
#
# ...

# %%
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Cleaning data

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
df["invoice_date"]=pd.to_datetime(df["invoice_date"],format="%d/%m/%Y")

# %%
df["year"]=df["invoice_date"].dt.year
df["month"]=df["invoice_date"].dt.month
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  year  month
# 0    Credit Card   2022-08-05          Kanyon  2022      8
# 1     Debit Card   2021-12-12  Forum Istanbul  2021     12
# 2           Cash   2021-11-09       Metrocity  2021     11
# 3    Credit Card   2021-05-16    Metropol AVM  2021      5
# 4           Cash   2021-10-24          Kanyon  2021     10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  datetime64[ns]
#  9   shopping_mall   99457 non-null  object
#  10  year            99457 non-null  int32
#  11  month           99457 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(2), object(6)
# memory usage: 8.3+ MB

# %% [markdown]
# # Analysis and visualizations

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  year  month
# 0    Credit Card   2022-08-05          Kanyon  2022      8
# 1     Debit Card   2021-12-12  Forum Istanbul  2021     12
# 2           Cash   2021-11-09       Metrocity  2021     11
# 3    Credit Card   2021-05-16    Metropol AVM  2021      5
# 4           Cash   2021-10-24          Kanyon  2021     10

# %% [markdown]
# # 1. How shopping preferences vary between genders

# %%
genders_category=df.groupby("gender")["category"].value_counts().reset_index()
genders_category
# Out:
#     gender         category  count
# 0   Female         Clothing  20652
# 1   Female        Cosmetics   9070
# 2   Female  Food & Beverage   8804
# 3   Female             Toys   6085
# 4   Female            Shoes   5967
# 5   Female         Souvenir   3017
# 6   Female       Technology   2981
# 7   Female            Books   2906
# 8     Male         Clothing  13835
# 9     Male        Cosmetics   6027
# 10    Male  Food & Beverage   5972
# 11    Male            Shoes   4067
# 12    Male             Toys   4002
# 13    Male            Books   2075
# 14    Male       Technology   2015
# 15    Male         Souvenir   1982

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df, x=df['category'], hue=df['gender'],palette=["#ffa09b", "#9ba0ff"])
plt.title('How shopping categories preferences vary between genders?',fontsize=16,fontweight="bold")
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 2. Who pay more, males or females?

# %%
gender_price=df.groupby("gender")["price"].sum().reset_index()
gender_price
# Out:
#    gender        price
# 0  Female  40931801.62
# 1    Male  27619564.29

# %%
plt.figure(figsize=(12,4))
plt.pie(gender_price["price"], labels=gender_price["gender"], colors=("#ffa09b", "#9ba0ff"),autopct='%1.1f%%', textprops={'fontsize':8})
plt.title('Who pay more, males or females?',fontsize=16,fontweight="bold")
plt.xlabel('Total price per gender')
plt.show()
